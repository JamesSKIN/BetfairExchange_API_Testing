# %%
import json
import requests

# %%
endpoint = "https://api.betfair.com/exchange/betting/rest/v1.0/"
 
header = { 'X-Application' : 'YZpYG9emX65Rzuw0', 'X-Authentication' : '5b/QEAjUXDa7UfDoj98JgG0BFfAEs4B/HDvzdalBUqA=' ,'content-type' : 'application/json' }
 
json_req='{"filter":{ }}'
 
url = endpoint + "listEventTypes/"
 
response = requests.post(url, data=json_req, headers=header)
 
 
print (json.dumps(json.loads(response.text), indent=3))
# Out:
# [
#    {
#       "eventType": {
#          "id": "1",
#          "name": "Soccer"
#       },
#       "marketCount": 26830
#    },
#    {
#       "eventType": {
#          "id": "2",
#          "name": "Tennis"
#       },
#       "marketCount": 2666
#    },
#    {
#       "eventType": {
#          "id": "3",
#          "name": "Golf"
#       },
#       "marketCount": 54
#    },
#    {
#       "eventType": {
#          "id": "4",
#          "name": "Cricket"
#       },
#       "marketCount": 265
#    },
#    {
#       "eventType": {
#          "id": "5",
#          "name": "Rugby Union"
#       },
#       "marketCount": 118
#    },
#    {
#       "eventType": {
#          "id": "1477",
#          "name": "Rugby League"
#       },
#       "marketCount": 28
#    },
#    {
#       "eventType": {
#          "id": "6",
#          "name": "Boxing"
#       },
#       "marketCount": 51
#    },
#    {
#       "eventType": {
#          "id": "7",
#          "name": "Horse Racing"
#       },
#       "marketCount": 934
#    },
#    {
#       "eventType": {
#          "id": "8",
#          "name": "Motor Sport"
#       },
#       "marketCount": 8
#    },
#    {
#       "eventType": {
#          "id": "27454571",
#          "name": "Esports"
#       },
#       "marketCount": 35
#    },
#    {
#       "eventType": {
#          "id": "10",
#          "name": "Special Bets"
#       },
#       "marketCount": 8
#    },
#    {
#       "eventType": {
#          "id": "998917",
#          "name": "Volleyball"
#       },
#       "marketCount": 8
#    },
#    {
#       "eventType": {
#          "id": "11",
#          "name": "Cycling"
#       },
#       "marketCount": 2
#    },
#    {
#       "eventType": {
#          "id": "2152880",
#          "name": "Gaelic Games"
#       },
#       "marketCount": 2
#    },
#    {
#       "eventType": {
#          "id": "6422",
#          "name": "Snooker"
#       },
#       "marketCount": 31
#    },
#    {
#       "eventType": {
#          "id": "6423",
#          "name": "American Football"
#       },
#       "marketCount": 126
#    },
#    {
#       "eventType": {
#          "id": "7511",
#          "name": "Baseball"
#       },
#       "marketCount": 13
#    },
#    {
#       "eventType": {
#          "id": "7522",
#          "name": "Basketball"
#       },
#       "marketCount": 489
#    },
#    {
#       "eventType": {
#          "id": "7524",
#          "name": "Ice Hockey"
#       },
#       "marketCount": 335
#    },
#    {
#       "eventType": {
#          "id": "61420",
#          "name": "Australian Rules"
#       },
#       "marketCount": 24
#    },
#    {
#       "eventType": {
#          "id": "468328",
#          "name": "Handball"
#       },
#       "marketCount": 120
#    },
#    {
#       "eventType": {
#          "id": "3503",
#          "name": "Darts"
#       },
#       "marketCount": 97
#    },
#    {
#       "eventType": {
#          "id": "26420387",
#          "name": "Mixed Martial Arts"
#       },
#       "marketCount": 55
#    },
#    {
#       "eventType": {
#          "id": "4339",
#          "name": "Greyhound Racing"
#       },
#       "marketCount": 197
#    },
#    {
#       "eventType": {
#          "id": "2378961",
#          "name": "Politics"
#       },
#       "marketCount": 141
#    }
# ]
